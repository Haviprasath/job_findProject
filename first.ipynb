# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file_path=r'C:\Users\chari\Test Python\cancer_immunotherapy.csv'
#1
df=pd.read_csv(file_path)
df
# Out:
#   PatientID  Age Gender TumorType ImmunotherapyType BiomarkerExpressionLevel  \
# 0      P001   45      F      Lung    PD-1 Inhibitor                     High
# 1      P002   67      M    Breast  CTLA-4 Inhibitor                      Low
# 2      P003   55      F  Melanoma   PD-L1 Inhibitor                   Medium
# 3      P004   70      M      Lung    PD-1 Inhibitor                     High
# 4      P005   38      F      Lung  CTLA-4 Inhibitor                   Medium
# 5      P006   60      F  Melanoma   PD-L1 Inhibitor                     High
# 6      P007   72      M    Breast    PD-1 Inhibitor                      Low
# 7      P008   50      F  Melanoma  CTLA-4 Inhibitor                   Medium
# 8      P009   65      M      Lung   PD-L1 Inhibitor                     High
# 9      P010   42      F    Breast    PD-1 Inhibitor                      Low
#
#      TreatmentResponse  SurvivalInMonths Relapse  MutationCount
# ...

# %%
df
# Out:
#   PatientID  Age Gender TumorType ImmunotherapyType BiomarkerExpressionLevel  \
# 0      P001   45      F      Lung    PD-1 Inhibitor                     High
# 1      P002   67      M    Breast  CTLA-4 Inhibitor                      Low
# 2      P003   55      F  Melanoma   PD-L1 Inhibitor                   Medium
# 3      P004   70      M      Lung    PD-1 Inhibitor                     High
# 4      P005   38      F      Lung  CTLA-4 Inhibitor                   Medium
# 5      P006   60      F  Melanoma   PD-L1 Inhibitor                     High
# 6      P007   72      M    Breast    PD-1 Inhibitor                      Low
# 7      P008   50      F  Melanoma  CTLA-4 Inhibitor                   Medium
# 8      P009   65      M      Lung   PD-L1 Inhibitor                     High
# 9      P010   42      F    Breast    PD-1 Inhibitor                      Low
#
#      TreatmentResponse  SurvivalInMonths Relapse  MutationCount
# ...

# %%
df.head()
# Out:
#   PatientID  Age Gender TumorType ImmunotherapyType BiomarkerExpressionLevel  \
# 0      P001   45      F      Lung    PD-1 Inhibitor                     High
# 1      P002   67      M    Breast  CTLA-4 Inhibitor                      Low
# 2      P003   55      F  Melanoma   PD-L1 Inhibitor                   Medium
# 3      P004   70      M      Lung    PD-1 Inhibitor                     High
# 4      P005   38      F      Lung  CTLA-4 Inhibitor                   Medium
#
#      TreatmentResponse  SurvivalInMonths Relapse  MutationCount
# 0     Partial Response                12     Yes            150
# 1       Stable Disease                20      No            320
# 2    Complete Response                36      No             50
# 3  Progressive Disease                10     Yes            200
# 4     Partial Response                24      No             80

# %%
df.iloc[:0,0:10]
# Out:
# Empty DataFrame
# Columns: [PatientID, Age, Gender, TumorType, ImmunotherapyType, BiomarkerExpressionLevel, TreatmentResponse, SurvivalInMonths, Relapse, MutationCount]
# Index: []

# %%
df.loc[1:1]
# Out:
#   PatientID  Age Gender TumorType ImmunotherapyType BiomarkerExpressionLevel  \
# 1      P002   67      M    Breast  CTLA-4 Inhibitor                      Low
#
#   TreatmentResponse  SurvivalInMonths Relapse  MutationCount
# 1    Stable Disease                20      No            320

# %%
df.columns[:]
# Out:
# Index(['PatientID', 'Age', 'Gender', 'TumorType', 'ImmunotherapyType',
#        'BiomarkerExpressionLevel', 'TreatmentResponse', 'SurvivalInMonths',
#        'Relapse', 'MutationCount'],
#       dtype='object')

# %%
df
# Out:
#   PatientID  Age Gender TumorType ImmunotherapyType BiomarkerExpressionLevel  \
# 0      P001   45      F      Lung    PD-1 Inhibitor                     High
# 1      P002   67      M    Breast  CTLA-4 Inhibitor                      Low
# 2      P003   55      F  Melanoma   PD-L1 Inhibitor                   Medium
# 3      P004   70      M      Lung    PD-1 Inhibitor                     High
# 4      P005   38      F      Lung  CTLA-4 Inhibitor                   Medium
# 5      P006   60      F  Melanoma   PD-L1 Inhibitor                     High
# 6      P007   72      M    Breast    PD-1 Inhibitor                      Low
# 7      P008   50      F  Melanoma  CTLA-4 Inhibitor                   Medium
# 8      P009   65      M      Lung   PD-L1 Inhibitor                     High
# 9      P010   42      F    Breast    PD-1 Inhibitor                      Low
#
#      TreatmentResponse  SurvivalInMonths Relapse  MutationCount
# ...

# %%
#plt.figure(figsize=(5,4))
#plt.boxplot(df)
#plt.show()

#data = [20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# Creating a boxplot
plt.boxplot(df)

# Adding title and labels
plt.title("Boxplot Example")
plt.ylabel("Age")

# Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\chari\OneDrive\Desktop\test1\first.ipynb Cell 9 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/chari/OneDrive/Desktop/test1/first.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> #plt.figure(figsize=(5,4))
#       <a href='vscode-notebook-cell:/c%3A/Users/chari/OneDrive/Desktop/test1/first.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> #plt.boxplot(df)
#       <a href='vscode-notebook-cell:/c%3A/Users/chari/OneDrive/Desktop/test1/first.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> #plt.show()
#    (...)
#       <a href='vscode-notebook-cell:/c%3A/Users/chari/OneDrive/Desktop/test1/first.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/chari/OneDrive/Desktop/test1/first.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> # Creating a boxplot
# ...

# %%
plt.figure(figsize=(5,8))
plt.boxplot(df['Age'])
plt.show()

# %%
df['Age'].mean()
# Out:
# 56.4

# %%
# Sample data
categories = pd.DataFrame({'Products': ['A', 'B', 'C'], 'Quantity': [30, 40, 30]})
categories.plot(kind='pie', y='Quantity', labels=categories['Products'], autopct='%1.1f%%')
plt.title("Product Distribution")
plt.ylabel("")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
df = pd.DataFrame({'Year': [2018, 2019, 2020, 2021, 2022], 
                   'Sales': [200, 250, 300, 350, 400]})

# Line plot
df.plot(x='Year', y='Sales', kind='line')
plt.title("Sales Over Years")
plt.ylabel("Sales")
plt.show()

# %%
df.plot(x='Year', y='Sales', kind='bar', color='skyblue')
plt.title("Sales by Year")
plt.ylabel("Sales")
plt.show()

# %%
df['Sales'].plot(kind='hist', bins=5, color='green')
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.show()

# %%
# Adding another column for comparison
df['Profit'] = [50, 60, 80, 90, 100]
df.plot(kind='scatter', x='Sales', y='Profit', color='red')
plt.title("Sales vs Profit")
plt.show()

# %%
df[['Sales', 'Profit']].plot(kind='box')
plt.title("Boxplot for Sales and Profit")
plt.show()

# %%
import seaborn as sns

# Correlation matrix heatmap
sns.heatmap(df[['Sales', 'Profit']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = [20, 25, 30, 35, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# KDE plot
sns.kdeplot(data, shade=True, color="blue")
plt.title("KDE Plot Example")
plt.xlabel("Values")
plt.show()
# Out:
# C:\Users\chari\AppData\Local\Temp\ipykernel_10492\1934584062.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True, color="blue")

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C', 'Category D']
values = [10, 24, 36, 18]

# Bar chart
plt.bar(categories, values, color='skyblue')
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a new graph
G = nx.Graph()

# Add nodes to the graph
G.add_node("A")
G.add_node("B")
G.add_node("C")
G.add_node("D")
G.add_node("E")

# Add edges to represent relationships/connections between nodes
G.add_edge("A", "B")
G.add_edge("A", "C")
G.add_edge("B", "D")
G.add_edge("C", "D")
G.add_edge("D", "E")

# Draw the graph
plt.figure(figsize=(8, 6))
nx.draw(G, with_labels=True, node_color="skyblue", node_size=1500, font_size=16, font_color="darkblue", font_weight="bold", edge_color="gray")
plt.title("Basic Network Diagram")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('img1.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply threshold
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# Noise removal with morphological operations
kernel = np.ones((3,3), np.uint8)
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=2)

# Sure background area
sure_bg = cv2.dilate(opening, kernel, iterations=3)

# Finding sure foreground area
dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
_, sure_fg = cv2.threshold(dist_transform, 0.7*dist_transform.max(), 255, 0)

# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg, sure_fg)

# Marker labelling
_, markers = cv2.connectedComponents(sure_fg)
markers = markers + 1
markers[unknown == 255] = 0

# Apply watershed
markers = cv2.watershed(image, markers)
image[markers == -1] = [255, 0, 0]  # Marking boundaries in red

# Displaying the result
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Watershed Segmentation")
plt.show()
